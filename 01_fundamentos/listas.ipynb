# %% [markdown]
# Treinando o uso de listas.

# %%
gastos = [12, 14, 15]
sum(gastos)
# Out:
# 41

# %%
animais = ['gato', 'cachorro', 'pássaro', 'cobra']
lista_animais_pega = animais[0:2]
print(lista_animais_pega)
# Out:
# ['gato', 'cachorro']

# %%
animais = ['gato', 'cachorro', 'pássaro', 'cobra']
len(animais)
# Out:
# 4

# %%
animais = ['gato', 'cachorro', 'pássaro', 'cobra']
animais.insert(2, 'pato')
print(animais)
# Out:
# ['gato', 'cachorro', 'pato', 'pássaro', 'cobra']

# %%
animais = ['gato', 'cachorro', 'pássaro', 'cobra']
animais.insert(2, 'pato')
print(animais)

del animais[1]
print(animais)
# Out:
# ['gato', 'cachorro', 'pato', 'pássaro', 'cobra']
# ['gato', 'pato', 'pássaro', 'cobra']

# %%
animais = ['gato', 'cachorro', 'pássaro', 'cobra']
animais.insert(2, 'pato')
print(animais)

del animais[1]
print(animais)

objetos = ['lápis', 'pincel', 'caderno']
nova_lista = objetos + animais
print(nova_lista)
# Out:
# ['gato', 'cachorro', 'pato', 'pássaro', 'cobra']
# ['gato', 'pato', 'pássaro', 'cobra']
# ['lápis', 'pincel', 'caderno', 'gato', 'pato', 'pássaro', 'cobra']

# %%
objetos = ['lápis', 'pincel', 'caderno']

nova_lista = 2 * objetos
print(nova_lista)
# Out:
# ['lápis', 'pincel', 'caderno', 'lápis', 'pincel', 'caderno']

# %%
abcde = ['a', 'b', 'c', 'd', 'e']
abc = ['a', 'b', 'c']
abd = ['a', 'b', 'd']

if abc == abd:
    print('Iguais')
else:
    print('Diferentes')
# Out:
# Diferentes

# %%
abcde = ['a', 'b', 'c', 'd', 'e']
abc = ['a', 'b', 'c']
abd = ['d', 'e']

lista_a = abc + abd

if lista_a == abcde:
    print('Iguais')
else:
    print('Diferentes')
# Out:
# Iguais

# %%
casas_pares = [216, 220, 222, 268, 270]
casas_pares = casas_pares[:3] + [232, 240, 252] + casas_pares[3:]

print(casas_pares)
# Out:
# [216, 220, 222, 232, 240, 252, 268, 270]

# %%
casas_pares = [216, 220, 222, 268, 270]
casas_pares = casas_pares[:3] + [232, 240, 252] + casas_pares[3:]
casas_pares.pop(3) #remove a do meio
casas_pares.pop() #remove final

print(casas_pares)
# Out:
# [216, 220, 222, 240, 252, 268]

# %%
notas = [7.3, 4.5, 6.7, 5.2, 8.6, 1.2, 9.4]
notas.sort()
print(notas)
notas.sort()
notas_uteis = notas[3:]
nota_final = sum(notas_uteis) / len(notas_uteis)

print(nota_final)
# Out:
# [1.2, 4.5, 5.2, 6.7, 7.3, 8.6, 9.4]
# 8.0
