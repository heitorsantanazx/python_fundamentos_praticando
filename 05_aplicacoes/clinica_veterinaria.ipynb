# %% [markdown]
# # Cadastro clínica versão 1

# %%
#---Cadstro do cliente---
cliente_nome = input('Digite o seu nome: ')
cliente_idade = int(input('Digite a sua idade: '))
cliente_endereco = input('Digite o seu endereço: ')
cliente_telefone = input('Digite o número do seu telefone: ')

#---Cadstro do pet---
animal_nome = input('Digite o nome do seu pet: ')
animal_tipo = input('Qual o tipo do seu pet: ')
animal_peso = float(input('Digite o peso do seu pet: '))
animal_doenca = input('Qual a doença do seu pet: ')

print()
print('Cadastro cliente conclúido!')
print(f'Nome: {cliente_nome}, idade: {cliente_idade}, endereço: {cliente_endereco} e contato: (81) 9 {cliente_telefone}')
print()
print('Cadastro pet concluído!')
print(f'Nome: {animal_nome}, tipo do animal: {animal_tipo}, peso: {animal_peso} KG e doença: {animal_doenca}')
# Out:
# Digite o seu nome:  Heitor
# Digite a sua idade:  30
# Digite o seu endereço:  Rua Valério Silva
# Digite o número do seu telefone:  95364224
# Digite o nome do seu pet:  Sakura
# Qual o tipo do seu pet:  Cão
# Digite o peso do seu pet:  40
# Qual a doença do seu pet:  Carrapato
# Cadastro cliente conclúido!
# Nome: Heitor, idade: 30, endereço: Rua Valério Silva e contato: (81) 9 95364224
#
# Cadastro pet concluído!
# Nome: Sakura, tipo do animal: Cão, peso: 40.0 KG e doença: Carrapato
